# %% [markdown]
# <a href="https://colab.research.google.com/github/Barath-188/DataAnalysis/blob/main/NMAssignmen1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83211ea6-c5bf-4741-bf94-ae30ec8d5627" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83211ea6-c5bf-4741-bf94-ae30ec8d5627">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df[['number of bedrooms','number of floors','Built Year','Renovation Year','Price']].describe()
# Out:
#        number of bedrooms  number of floors    Built Year  Renovation Year  \
# count        14620.000000      14620.000000  14620.000000     14620.000000
# mean             3.379343          1.502360   1970.926402        90.924008
# std              0.938719          0.540239     29.493625       416.216661
# min              1.000000          1.000000   1900.000000         0.000000
# 25%              3.000000          1.000000   1951.000000         0.000000
# 50%              3.000000          1.500000   1975.000000         0.000000
# 75%              4.000000          2.000000   1997.000000         0.000000
# max             33.000000          3.500000   2015.000000      2015.000000
#
#               Price
# count  1.462000e+04
# mean   5.389322e+05
# std    3.675324e+05
# min    7.800000e+04
# 25%    3.200000e+05
# 50%    4.500000e+05
# 75%    6.450000e+05
# max    7.700000e+06

# %% [markdown]
# Univariate

# %%
sns.histplot(df.Price,kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=df,x='Built Year')
# Out:
# <Axes: xlabel='Built Year', ylabel='Count'>

# %%
sns.countplot(data=df,x='number of floors')
# Out:
# <Axes: xlabel='number of floors', ylabel='count'>

# %% [markdown]
# Bi-variate

# %%
sns.scatterplot(data=df,x='living area',y='Price')
# Out:
# <Axes: xlabel='living area', ylabel='Price'>

# %%
sns.countplot(data=df,x='Price',hue='number of floors')
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.boxplot(data=df,x='number of bedrooms',y='Price')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(data=df,x='number of bedrooms',y='Price')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %% [markdown]
# Multivariate

# %%
sns.pairplot(df,hue="number of floors")

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
